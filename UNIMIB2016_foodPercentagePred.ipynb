# %% [markdown]
# # 1. Importar librerias

# %% [markdown]
# Cargamos las librerias necesarias: Keras y Tensorflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.keras as tf

from google.colab import drive
from sklearn.model_selection import train_test_split
from keras import backend
from keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import applications
from tensorflow.keras import optimizers

from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Flatten, Conv2D, MaxPooling2D, Dense, Dropout

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # 2. Preparado de los datos

# %% [markdown]
# Desde nuestra raiz de Google Drive, vamos a cargar el fichero .zip que ha sido proporcionado. Una vez extraido hacemos el manejo de los ficheros para poder conformar los datos de entrenamiento (70%), validacion (15%) y testing (15%). El fichero .zip consta de un .csv con el porcentaje de pixeles de cada una de las imagenes que pertenecen a comida y una carpeta con todas las imagenes. Todas las imagenes tienen unas resolucion de 640 x 480.

# %%
# Montamos el Google Drive en el directorio del proyecto y descomprimios el fichero con los datos
drive.mount('/content/gdrive')
# !unzip -n '/content/gdrive/My Drive/DL_UNIMIB2016.zip' >> /dev/null

# Especificamos los paths al directorio que contiene las imagenes y al fichero con los porcentajes
data_path = 'UNIMIB2016/'
imgs_path = data_path + "images/"
percentages_path = data_path + "percentage.csv"

# Leemos el fichero CSV con los porcentajes
percentages = pd.read_csv(percentages_path, dtype = {"class": "float"})
# Out:
# Mounted at /content/gdrive

# %%
# Creamos las tres particiones de datos: entrenamiento, validación y test
seed = 0
train_data, test_data = train_test_split(percentages, test_size=0.3, random_state=seed)
val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=seed)

# Actualizamos los indices de cada particion
train_data = train_data.reset_index(drop=True)
val_data = val_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

# Especificamos una serie de parámetros dependientes del conjunto de datos
x_col = 'image_name'          # nombres de las columnas en el fichero CSV
y_col = 'food_pixels'

# Generamos los batches con los datos para las tres particiones
batch_size = 64

# Hacemos una normalizacion de los datos para que los valores de las capas rgb esten en un intervalo de 0 a 1
datagen = ImageDataGenerator(rescale=1./255)
# En cuanto a los datos de entrenamiento, tambien aplicamos transformaciones para poder hacer Data Augmentation
datagenTrain = ImageDataGenerator(rescale=1./255, horizontal_flip=True, vertical_flip=True)

train_generator = datagenTrain.flow_from_dataframe(dataframe=train_data, directory=imgs_path, x_col=x_col, y_col=y_col,
                                              class_mode="raw", target_size=(224,224), shuffle=False,
                                              batch_size=batch_size)
val_generator = datagen.flow_from_dataframe(dataframe=val_data, directory=imgs_path, x_col=x_col, y_col=y_col,
                                          class_mode="raw", target_size=(224,224), shuffle=False,
                                          batch_size=batch_size)
test_generator = datagen.flow_from_dataframe(dataframe=test_data, directory=imgs_path, x_col=x_col, y_col=y_col,
                                             class_mode="raw", target_size=(224,224), shuffle=False,
                                             batch_size=batch_size)
# Out:
# Found 718 validated image filenames.
# Found 154 validated image filenames.
# Found 155 validated image filenames.

# %% [markdown]
# # 3. Construccion de modelos

# %% [markdown]
# Construimos las funciones necesarias para solucionar el problema de prediccion de 3 maneras distintas. Haremos Fine Tunning con 2 de los modelos, mientras que con el otro, solo entrenaremos las ultimas capas.

# %%
# Definicion de la funcion de perdida rmse
def root_mean_squared_error(y_true, y_pred):
        return backend.sqrt(backend.mean(backend.square(y_pred - y_true)))

def VGG16_FineTuningModel():
  # Cargamos el modelo preentrenado con los pesos de imagenet para hacer fine tuning
  base_model = applications.VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

  # Añadimos nuevas capas al final para adaptar el modelo a nuestro problema
  x = base_model.output
  x = GlobalAveragePooling2D()(x)
  x = Dense(1024, activation='relu')(x)

  # Añadimos una última capa completamente conectada, la salida sera lineal
  predictions = Dense(1)(x)

  # Creamos el modelo final y lo compilamos
  model = Model(inputs=[base_model.input], outputs=[predictions])
  model.summary()

  model.compile(optimizer = optimizers.Adam(learning_rate=0.0001), loss = root_mean_squared_error)

  # Configuramos el earlystopping, despues de 10 epocas si no mejora, paramos el entrenamiento
  es = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    mode=min
  )

  # Almacenamos la epoch con mejores pesos para hacer un val_loss minimo
  mc = ModelCheckpoint(
    'best_m.h5',
    monitor='val_loss',
    mode='min',
    verbose=1,
    save_best_only=True
  )

  # Entrenamos el modelo
  model.fit(train_generator,
          epochs=70,
          verbose=2,
          callbacks=[es, mc],
          steps_per_epoch=len(train_data)/batch_size,
          validation_data=val_generator,
          validation_steps=len(val_data)/batch_size)
  return model


def VGG16_LastLayersModel():
  base_model = applications.VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

  # Ponemos todas las capas como no entrenables, solo entrenaremos las capas finales
  for layer in base_model.layers:
    layer.trainable = False

  x = base_model.output
  x = GlobalAveragePooling2D()(x)
  x = Dense(1024, activation='relu')(x)
  predictions = Dense(1)(x)

  model = Model(inputs=[base_model.input], outputs=[predictions])
  model.summary()

  model.compile(optimizer = optimizers.Adam(learning_rate=0.01), loss = root_mean_squared_error)

  es = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    mode=min
  )

  mc = ModelCheckpoint(
    'best_m.h5',
    monitor='val_loss',
    mode='min',
    verbose=1,
    save_best_only=True
  )

  model.fit(train_generator,
          epochs=70,
          verbose=2,
          callbacks=[es, mc],
          steps_per_epoch=len(train_data)/batch_size,
          validation_data=val_generator,
          validation_steps=len(val_data)/batch_size)
  return model


def InceptionResNetV2_FineTuningModel():
  # Cargamos el modelo preentrenado con los pesos de imagenet para hacer fine tuning
  base_model = applications.InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(224,224,3))

  x = base_model.output
  x = GlobalAveragePooling2D()(x)
  x = Dense(1024, activation='relu')(x)
  predictions = Dense(1)(x)

  model = Model(inputs=[base_model.input], outputs=[predictions])
  model.summary()

  model.compile(optimizer = optimizers.Adam(learning_rate=0.0001), loss = root_mean_squared_error)

  es = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    mode=min
  )

  mc = ModelCheckpoint(
    'best_m.h5',
    monitor='val_loss',
    mode='min',
    verbose=1,
    save_best_only=True
  )

  model.fit(train_generator,
          epochs=70,
          verbose=2,
          callbacks=[es, mc],
          steps_per_epoch=len(train_data)/batch_size,
          validation_data=val_generator,
          validation_steps=len(val_data)/batch_size)
  return model
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x7b6f528ceb00>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:

# %% [markdown]
# # 4. Ejecucion de entrenamiento

# %%
# Ejecutamos la funcion del modelo
VGG16FineTuningModel = VGG16_FineTuningModel()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 15241025 (58.14 MB)
# Trainable params: 15241025 (58.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:EarlyStopping mode <built-in function min> is unknown, fallback to auto mode.
# Epoch 1/70
#
# Epoch 1: val_loss improved from inf to 5.34755, saving model to best_m.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 11/11 - 74s - loss: 7.5327 - val_loss: 5.3476 - 74s/epoch - 7s/step
# Epoch 2/70
#
# Epoch 2: val_loss improved from 5.34755 to 3.97675, saving model to best_m.h5
# 11/11 - 12s - loss: 4.2465 - val_loss: 3.9767 - 12s/epoch - 1s/step
# Epoch 3/70
#
# Epoch 3: val_loss improved from 3.97675 to 3.09228, saving model to best_m.h5
# 11/11 - 12s - loss: 3.2100 - val_loss: 3.0923 - 12s/epoch - 1s/step
# Epoch 4/70
#
# Epoch 4: val_loss did not improve from 3.09228
# 11/11 - 11s - loss: 2.1959 - val_loss: 3.6142 - 11s/epoch - 968ms/step
# Epoch 5/70
#
# Epoch 5: val_loss did not improve from 3.09228
# 11/11 - 11s - loss: 2.6712 - val_loss: 3.6658 - 11s/epoch - 989ms/step
# Epoch 6/70
#
# Epoch 6: val_loss improved from 3.09228 to 2.03407, saving model to best_m.h5
# 11/11 - 12s - loss: 2.2463 - val_loss: 2.0341 - 12s/epoch - 1s/step
# Epoch 7/70
#
# Epoch 7: val_loss improved from 2.03407 to 1.89654, saving model to best_m.h5
# 11/11 - 12s - loss: 1.9271 - val_loss: 1.8965 - 12s/epoch - 1s/step
# Epoch 8/70
#
# Epoch 8: val_loss did not improve from 1.89654
# 11/11 - 11s - loss: 2.2603 - val_loss: 2.4367 - 11s/epoch - 1s/step
# Epoch 9/70
#
# Epoch 9: val_loss did not improve from 1.89654
# 11/11 - 11s - loss: 1.8603 - val_loss: 2.3089 - 11s/epoch - 1s/step
# Epoch 10/70
#
# Epoch 10: val_loss did not improve from 1.89654
# 11/11 - 12s - loss: 1.7961 - val_loss: 1.9264 - 12s/epoch - 1s/step
# Epoch 11/70
#
# Epoch 11: val_loss improved from 1.89654 to 1.72000, saving model to best_m.h5
# 11/11 - 12s - loss: 1.4517 - val_loss: 1.7200 - 12s/epoch - 1s/step
# Epoch 12/70
#
# Epoch 12: val_loss improved from 1.72000 to 1.60371, saving model to best_m.h5
# 11/11 - 12s - loss: 1.4127 - val_loss: 1.6037 - 12s/epoch - 1s/step
# Epoch 13/70
#
# Epoch 13: val_loss improved from 1.60371 to 1.55298, saving model to best_m.h5
# 11/11 - 12s - loss: 1.3048 - val_loss: 1.5530 - 12s/epoch - 1s/step
# Epoch 14/70
#
# Epoch 14: val_loss did not improve from 1.55298
# 11/11 - 11s - loss: 2.1363 - val_loss: 1.8904 - 11s/epoch - 992ms/step
# Epoch 15/70
#
# Epoch 15: val_loss did not improve from 1.55298
# 11/11 - 11s - loss: 1.4954 - val_loss: 1.5924 - 11s/epoch - 988ms/step
# Epoch 16/70
#
# Epoch 16: val_loss did not improve from 1.55298
# 11/11 - 12s - loss: 1.2598 - val_loss: 1.6650 - 12s/epoch - 1s/step
# Epoch 17/70
#
# Epoch 17: val_loss did not improve from 1.55298
# 11/11 - 13s - loss: 1.2552 - val_loss: 1.8599 - 13s/epoch - 1s/step
# Epoch 18/70
#
# Epoch 18: val_loss did not improve from 1.55298
# 11/11 - 11s - loss: 1.3548 - val_loss: 1.6010 - 11s/epoch - 1s/step
# Epoch 19/70
#
# Epoch 19: val_loss did not improve from 1.55298
# 11/11 - 11s - loss: 1.2506 - val_loss: 1.6175 - 11s/epoch - 1s/step
# Epoch 20/70
#
# Epoch 20: val_loss did not improve from 1.55298
# 11/11 - 11s - loss: 1.3006 - val_loss: 2.0096 - 11s/epoch - 1s/step
# Epoch 21/70
#
# Epoch 21: val_loss did not improve from 1.55298
# 11/11 - 11s - loss: 1.3090 - val_loss: 1.5667 - 11s/epoch - 1s/step
# Epoch 22/70
#
# Epoch 22: val_loss improved from 1.55298 to 1.36466, saving model to best_m.h5
# 11/11 - 11s - loss: 0.9389 - val_loss: 1.3647 - 11s/epoch - 1s/step
# Epoch 23/70
#
# Epoch 23: val_loss did not improve from 1.36466
# 11/11 - 11s - loss: 1.1360 - val_loss: 1.4202 - 11s/epoch - 1s/step
# Epoch 24/70
#
# Epoch 24: val_loss did not improve from 1.36466
# 11/11 - 11s - loss: 1.1886 - val_loss: 1.5685 - 11s/epoch - 1s/step
# Epoch 25/70
#
# Epoch 25: val_loss did not improve from 1.36466
# 11/11 - 12s - loss: 0.8971 - val_loss: 1.4846 - 12s/epoch - 1s/step
# Epoch 26/70
#
# Epoch 26: val_loss did not improve from 1.36466
# 11/11 - 11s - loss: 0.8211 - val_loss: 1.7015 - 11s/epoch - 1s/step
# Epoch 27/70
#
# Epoch 27: val_loss did not improve from 1.36466
# 11/11 - 11s - loss: 1.2446 - val_loss: 1.4899 - 11s/epoch - 990ms/step
# Epoch 28/70
#
# Epoch 28: val_loss improved from 1.36466 to 1.34724, saving model to best_m.h5
# 11/11 - 12s - loss: 1.3845 - val_loss: 1.3472 - 12s/epoch - 1s/step
# Epoch 29/70
#
# Epoch 29: val_loss improved from 1.34724 to 1.31811, saving model to best_m.h5
# 11/11 - 12s - loss: 0.8954 - val_loss: 1.3181 - 12s/epoch - 1s/step
# Epoch 30/70
#
# Epoch 30: val_loss did not improve from 1.31811
# 11/11 - 11s - loss: 1.1378 - val_loss: 1.4709 - 11s/epoch - 1s/step
# Epoch 31/70
#
# Epoch 31: val_loss did not improve from 1.31811
# 11/11 - 11s - loss: 1.0587 - val_loss: 1.6017 - 11s/epoch - 1s/step
# Epoch 32/70
#
# Epoch 32: val_loss improved from 1.31811 to 1.24363, saving model to best_m.h5
# 11/11 - 13s - loss: 0.8250 - val_loss: 1.2436 - 13s/epoch - 1s/step
# Epoch 33/70
#
# Epoch 33: val_loss did not improve from 1.24363
# 11/11 - 13s - loss: 0.5903 - val_loss: 1.3389 - 13s/epoch - 1s/step
# Epoch 34/70
#
# Epoch 34: val_loss did not improve from 1.24363
# 11/11 - 12s - loss: 0.6730 - val_loss: 1.2450 - 12s/epoch - 1s/step
# Epoch 35/70
#
# Epoch 35: val_loss did not improve from 1.24363
# 11/11 - 11s - loss: 1.4561 - val_loss: 1.4717 - 11s/epoch - 986ms/step
# Epoch 36/70
#
# Epoch 36: val_loss did not improve from 1.24363
# 11/11 - 11s - loss: 1.7098 - val_loss: 2.4361 - 11s/epoch - 1s/step
# Epoch 37/70
#
# Epoch 37: val_loss did not improve from 1.24363
# 11/11 - 11s - loss: 1.2684 - val_loss: 1.2781 - 11s/epoch - 1s/step
# Epoch 38/70
#
# Epoch 38: val_loss did not improve from 1.24363
# 11/11 - 12s - loss: 1.0303 - val_loss: 1.4483 - 12s/epoch - 1s/step
# Epoch 39/70
#
# Epoch 39: val_loss did not improve from 1.24363
# 11/11 - 11s - loss: 0.7841 - val_loss: 1.5717 - 11s/epoch - 1s/step
# Epoch 40/70
#
# Epoch 40: val_loss did not improve from 1.24363
# 11/11 - 11s - loss: 1.4636 - val_loss: 1.5420 - 11s/epoch - 974ms/step
# Epoch 41/70
#
# Epoch 41: val_loss did not improve from 1.24363
# 11/11 - 11s - loss: 1.1282 - val_loss: 1.2684 - 11s/epoch - 1s/step
# Epoch 42/70
#
# Epoch 42: val_loss did not improve from 1.24363
# 11/11 - 13s - loss: 0.7365 - val_loss: 1.4077 - 13s/epoch - 1s/step
# Epoch 42: early stopping

# %%
VGG16LastLayersModel = VGG16_LastLayersModel()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 1024)              525312
#
#  dense_3 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 15241025 (58.14 MB)
# Trainable params: 526337 (2.01 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# WARNING:tensorflow:EarlyStopping mode <built-in function min> is unknown, fallback to auto mode.
# Epoch 1/70
#
# Epoch 1: val_loss improved from inf to 4.14039, saving model to best_m.h5
# 11/11 - 9s - loss: 5.6273 - val_loss: 4.1404 - 9s/epoch - 832ms/step
# Epoch 2/70
#
# Epoch 2: val_loss improved from 4.14039 to 3.59665, saving model to best_m.h5
# 11/11 - 6s - loss: 3.5999 - val_loss: 3.5966 - 6s/epoch - 557ms/step
# Epoch 3/70
#
# Epoch 3: val_loss improved from 3.59665 to 3.20762, saving model to best_m.h5
# 11/11 - 7s - loss: 3.3580 - val_loss: 3.2076 - 7s/epoch - 624ms/step
# Epoch 4/70
#
# Epoch 4: val_loss improved from 3.20762 to 2.72371, saving model to best_m.h5
# 11/11 - 6s - loss: 2.9221 - val_loss: 2.7237 - 6s/epoch - 559ms/step
# Epoch 5/70
#
# Epoch 5: val_loss improved from 2.72371 to 2.53439, saving model to best_m.h5
# 11/11 - 7s - loss: 2.7340 - val_loss: 2.5344 - 7s/epoch - 615ms/step
# Epoch 6/70
#
# Epoch 6: val_loss improved from 2.53439 to 2.42050, saving model to best_m.h5
# 11/11 - 6s - loss: 2.5859 - val_loss: 2.4205 - 6s/epoch - 558ms/step
# Epoch 7/70
#
# Epoch 7: val_loss improved from 2.42050 to 2.37732, saving model to best_m.h5
# 11/11 - 7s - loss: 2.4247 - val_loss: 2.3773 - 7s/epoch - 615ms/step
# Epoch 8/70
#
# Epoch 8: val_loss improved from 2.37732 to 2.33414, saving model to best_m.h5
# 11/11 - 6s - loss: 2.4418 - val_loss: 2.3341 - 6s/epoch - 556ms/step
# Epoch 9/70
#
# Epoch 9: val_loss improved from 2.33414 to 2.27560, saving model to best_m.h5
# 11/11 - 7s - loss: 2.3840 - val_loss: 2.2756 - 7s/epoch - 616ms/step
# Epoch 10/70
#
# Epoch 10: val_loss improved from 2.27560 to 2.24628, saving model to best_m.h5
# 11/11 - 6s - loss: 2.3531 - val_loss: 2.2463 - 6s/epoch - 561ms/step
# Epoch 11/70
#
# Epoch 11: val_loss did not improve from 2.24628
# 11/11 - 7s - loss: 2.3806 - val_loss: 2.4364 - 7s/epoch - 599ms/step
# Epoch 12/70
#
# Epoch 12: val_loss improved from 2.24628 to 2.17453, saving model to best_m.h5
# 11/11 - 6s - loss: 2.3218 - val_loss: 2.1745 - 6s/epoch - 551ms/step
# Epoch 13/70
#
# Epoch 13: val_loss did not improve from 2.17453
# 11/11 - 7s - loss: 2.2540 - val_loss: 2.2091 - 7s/epoch - 606ms/step
# Epoch 14/70
#
# Epoch 14: val_loss did not improve from 2.17453
# 11/11 - 6s - loss: 2.2872 - val_loss: 3.0023 - 6s/epoch - 542ms/step
# Epoch 15/70
#
# Epoch 15: val_loss did not improve from 2.17453
# 11/11 - 7s - loss: 2.4029 - val_loss: 2.4486 - 7s/epoch - 605ms/step
# Epoch 16/70
#
# Epoch 16: val_loss improved from 2.17453 to 2.15022, saving model to best_m.h5
# 11/11 - 6s - loss: 2.1737 - val_loss: 2.1502 - 6s/epoch - 563ms/step
# Epoch 17/70
#
# Epoch 17: val_loss did not improve from 2.15022
# 11/11 - 7s - loss: 2.0742 - val_loss: 2.3326 - 7s/epoch - 612ms/step
# Epoch 18/70
#
# Epoch 18: val_loss did not improve from 2.15022
# 11/11 - 6s - loss: 2.1231 - val_loss: 2.2990 - 6s/epoch - 546ms/step
# Epoch 19/70
#
# Epoch 19: val_loss did not improve from 2.15022
# 11/11 - 7s - loss: 2.2519 - val_loss: 2.6597 - 7s/epoch - 611ms/step
# Epoch 20/70
#
# Epoch 20: val_loss did not improve from 2.15022
# 11/11 - 6s - loss: 2.0997 - val_loss: 2.3595 - 6s/epoch - 551ms/step
# Epoch 21/70
#
# Epoch 21: val_loss did not improve from 2.15022
# 11/11 - 7s - loss: 2.2603 - val_loss: 2.1788 - 7s/epoch - 602ms/step
# Epoch 22/70
#
# Epoch 22: val_loss did not improve from 2.15022
# 11/11 - 6s - loss: 2.0932 - val_loss: 2.1556 - 6s/epoch - 548ms/step
# Epoch 23/70
#
# Epoch 23: val_loss improved from 2.15022 to 2.14149, saving model to best_m.h5
# 11/11 - 7s - loss: 2.0016 - val_loss: 2.1415 - 7s/epoch - 623ms/step
# Epoch 24/70
#
# Epoch 24: val_loss improved from 2.14149 to 2.13574, saving model to best_m.h5
# 11/11 - 6s - loss: 2.0103 - val_loss: 2.1357 - 6s/epoch - 557ms/step
# Epoch 25/70
#
# Epoch 25: val_loss did not improve from 2.13574
# 11/11 - 7s - loss: 2.2259 - val_loss: 3.3870 - 7s/epoch - 610ms/step
# Epoch 26/70
#
# Epoch 26: val_loss did not improve from 2.13574
# 11/11 - 7s - loss: 2.3115 - val_loss: 2.3567 - 7s/epoch - 619ms/step
# Epoch 27/70
#
# Epoch 27: val_loss did not improve from 2.13574
# 11/11 - 6s - loss: 2.4162 - val_loss: 2.2254 - 6s/epoch - 549ms/step
# Epoch 28/70
#
# Epoch 28: val_loss improved from 2.13574 to 2.11492, saving model to best_m.h5
# 11/11 - 7s - loss: 2.0178 - val_loss: 2.1149 - 7s/epoch - 625ms/step
# Epoch 29/70
#
# Epoch 29: val_loss did not improve from 2.11492
# 11/11 - 6s - loss: 1.9703 - val_loss: 2.2237 - 6s/epoch - 537ms/step
# Epoch 30/70
#
# Epoch 30: val_loss did not improve from 2.11492
# 11/11 - 6s - loss: 2.1296 - val_loss: 2.2516 - 6s/epoch - 545ms/step
# Epoch 31/70
#
# Epoch 31: val_loss did not improve from 2.11492
# 11/11 - 6s - loss: 2.1232 - val_loss: 2.1636 - 6s/epoch - 543ms/step
# Epoch 32/70
#
# Epoch 32: val_loss did not improve from 2.11492
# 11/11 - 8s - loss: 2.1355 - val_loss: 2.6199 - 8s/epoch - 714ms/step
# Epoch 33/70
#
# Epoch 33: val_loss did not improve from 2.11492
# 11/11 - 6s - loss: 1.9934 - val_loss: 2.3144 - 6s/epoch - 559ms/step
# Epoch 34/70
#
# Epoch 34: val_loss did not improve from 2.11492
# 11/11 - 7s - loss: 2.1215 - val_loss: 2.5146 - 7s/epoch - 600ms/step
# Epoch 35/70
#
# Epoch 35: val_loss did not improve from 2.11492
# 11/11 - 6s - loss: 2.2550 - val_loss: 2.1977 - 6s/epoch - 559ms/step
# Epoch 36/70
#
# Epoch 36: val_loss did not improve from 2.11492
# 11/11 - 7s - loss: 1.9090 - val_loss: 2.1962 - 7s/epoch - 591ms/step
# Epoch 37/70
#
# Epoch 37: val_loss did not improve from 2.11492
# 11/11 - 7s - loss: 2.0176 - val_loss: 2.3468 - 7s/epoch - 594ms/step
# Epoch 38/70
#
# Epoch 38: val_loss did not improve from 2.11492
# 11/11 - 6s - loss: 2.0781 - val_loss: 2.2143 - 6s/epoch - 538ms/step
# Epoch 38: early stopping

# %%
InceptionResNetV2FineTuningModel = InceptionResNetV2_FineTuningModel()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_406 (Conv2D)         (None, 111, 111, 32)         864       ['input_5[0][0]']
#
#  batch_normalization_406 (B  (None, 111, 111, 32)         96        ['conv2d_406[0][0]']
#  atchNormalization)
#
#  activation_406 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
#  conv2d_407 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_406[0][0]']
#
#  batch_normalization_407 (B  (None, 109, 109, 32)         96        ['conv2d_407[0][0]']
#  atchNormalization)
#
#  activation_407 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_407[0][0
#  )                                                                  ]']
#
#  conv2d_408 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_407[0][0]']
#
#  batch_normalization_408 (B  (None, 109, 109, 64)         192       ['conv2d_408[0][0]']
#  atchNormalization)
#
#  activation_408 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_408[0][0
#  )                                                                  ]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 54, 54, 64)           0         ['activation_408[0][0]']
#  g2D)
#
#  conv2d_409 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_8[0][0]']
#
#  batch_normalization_409 (B  (None, 54, 54, 80)           240       ['conv2d_409[0][0]']
#  atchNormalization)
#
#  activation_409 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_409[0][0
#  )                                                                  ]']
#
#  conv2d_410 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_409[0][0]']
#
#  batch_normalization_410 (B  (None, 52, 52, 192)          576       ['conv2d_410[0][0]']
#  atchNormalization)
#
#  activation_410 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_410[0][0
#  )                                                                  ]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 25, 25, 192)          0         ['activation_410[0][0]']
#  g2D)
#
#  conv2d_414 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_9[0][0]']
#
#  batch_normalization_414 (B  (None, 25, 25, 64)           192       ['conv2d_414[0][0]']
#  atchNormalization)
#
#  activation_414 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_414[0][0
#  )                                                                  ]']
#
#  conv2d_412 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_9[0][0]']
#
#  conv2d_415 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_414[0][0]']
#
#  batch_normalization_412 (B  (None, 25, 25, 48)           144       ['conv2d_412[0][0]']
#  atchNormalization)
#
#  batch_normalization_415 (B  (None, 25, 25, 96)           288       ['conv2d_415[0][0]']
#  atchNormalization)
#
#  activation_412 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_412[0][0
#  )                                                                  ]']
#
#  activation_415 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_415[0][0
#  )                                                                  ]']
#
#  average_pooling2d_2 (Avera  (None, 25, 25, 192)          0         ['max_pooling2d_9[0][0]']
#  gePooling2D)
#
#  conv2d_411 (Conv2D)         (None, 25, 25, 96)           18432     ['max_pooling2d_9[0][0]']
#
#  conv2d_413 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_412[0][0]']
#
#  conv2d_416 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_415[0][0]']
#
#  conv2d_417 (Conv2D)         (None, 25, 25, 64)           12288     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_411 (B  (None, 25, 25, 96)           288       ['conv2d_411[0][0]']
#  atchNormalization)
#
#  batch_normalization_413 (B  (None, 25, 25, 64)           192       ['conv2d_413[0][0]']
#  atchNormalization)
#
#  batch_normalization_416 (B  (None, 25, 25, 96)           288       ['conv2d_416[0][0]']
#  atchNormalization)
#
#  batch_normalization_417 (B  (None, 25, 25, 64)           192       ['conv2d_417[0][0]']
#  atchNormalization)
#
#  activation_411 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_411[0][0
#  )                                                                  ]']
#
#  activation_413 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_413[0][0
#  )                                                                  ]']
#
#  activation_416 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_416[0][0
#  )                                                                  ]']
#
#  activation_417 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_417[0][0
#  )                                                                  ]']
#
#  mixed_5b (Concatenate)      (None, 25, 25, 320)          0         ['activation_411[0][0]',
#                                                                      'activation_413[0][0]',
#                                                                      'activation_416[0][0]',
#                                                                      'activation_417[0][0]']
#
#  conv2d_421 (Conv2D)         (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_421 (B  (None, 25, 25, 32)           96        ['conv2d_421[0][0]']
#  atchNormalization)
#
#  activation_421 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_421[0][0
#  )                                                                  ]']
#
#  conv2d_419 (Conv2D)         (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_422 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_421[0][0]']
#
#  batch_normalization_419 (B  (None, 25, 25, 32)           96        ['conv2d_419[0][0]']
#  atchNormalization)
#
#  batch_normalization_422 (B  (None, 25, 25, 48)           144       ['conv2d_422[0][0]']
#  atchNormalization)
#
#  activation_419 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_419[0][0
#  )                                                                  ]']
#
#  activation_422 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_422[0][0
#  )                                                                  ]']
#
#  conv2d_418 (Conv2D)         (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_420 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_419[0][0]']
#
#  conv2d_423 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_422[0][0]']
#
#  batch_normalization_418 (B  (None, 25, 25, 32)           96        ['conv2d_418[0][0]']
#  atchNormalization)
#
#  batch_normalization_420 (B  (None, 25, 25, 32)           96        ['conv2d_420[0][0]']
#  atchNormalization)
#
#  batch_normalization_423 (B  (None, 25, 25, 64)           192       ['conv2d_423[0][0]']
#  atchNormalization)
#
#  activation_418 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_418[0][0
#  )                                                                  ]']
#
#  activation_420 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_420[0][0
#  )                                                                  ]']
#
#  activation_423 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_423[0][0
#  )                                                                  ]']
#
#  block35_1_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_418[0][0]',
#  te)                                                                 'activation_420[0][0]',
#                                                                      'activation_423[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_80 (Cus  (None, 25, 25, 320)          0         ['mixed_5b[0][0]',
#  tomScaleLayer)                                                      'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_80[0][0]'
#                                                                     ]
#
#  conv2d_427 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_427 (B  (None, 25, 25, 32)           96        ['conv2d_427[0][0]']
#  atchNormalization)
#
#  activation_427 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_427[0][0
#  )                                                                  ]']
#
#  conv2d_425 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_428 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_427[0][0]']
#
#  batch_normalization_425 (B  (None, 25, 25, 32)           96        ['conv2d_425[0][0]']
#  atchNormalization)
#
#  batch_normalization_428 (B  (None, 25, 25, 48)           144       ['conv2d_428[0][0]']
#  atchNormalization)
#
#  activation_425 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_425[0][0
#  )                                                                  ]']
#
#  activation_428 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_428[0][0
#  )                                                                  ]']
#
#  conv2d_424 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_426 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_425[0][0]']
#
#  conv2d_429 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_428[0][0]']
#
#  batch_normalization_424 (B  (None, 25, 25, 32)           96        ['conv2d_424[0][0]']
#  atchNormalization)
#
#  batch_normalization_426 (B  (None, 25, 25, 32)           96        ['conv2d_426[0][0]']
#  atchNormalization)
#
#  batch_normalization_429 (B  (None, 25, 25, 64)           192       ['conv2d_429[0][0]']
#  atchNormalization)
#
#  activation_424 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_424[0][0
#  )                                                                  ]']
#
#  activation_426 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_426[0][0
#  )                                                                  ]']
#
#  activation_429 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_429[0][0
#  )                                                                  ]']
#
#  block35_2_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_424[0][0]',
#  te)                                                                 'activation_426[0][0]',
#                                                                      'activation_429[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_81 (Cus  (None, 25, 25, 320)          0         ['block35_1_ac[0][0]',
#  tomScaleLayer)                                                      'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_81[0][0]'
#                                                                     ]
#
#  conv2d_433 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_433 (B  (None, 25, 25, 32)           96        ['conv2d_433[0][0]']
#  atchNormalization)
#
#  activation_433 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_433[0][0
#  )                                                                  ]']
#
#  conv2d_431 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_434 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_433[0][0]']
#
#  batch_normalization_431 (B  (None, 25, 25, 32)           96        ['conv2d_431[0][0]']
#  atchNormalization)
#
#  batch_normalization_434 (B  (None, 25, 25, 48)           144       ['conv2d_434[0][0]']
#  atchNormalization)
#
#  activation_431 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_431[0][0
#  )                                                                  ]']
#
#  activation_434 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_434[0][0
#  )                                                                  ]']
#
#  conv2d_430 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_432 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_431[0][0]']
#
#  conv2d_435 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_434[0][0]']
#
#  batch_normalization_430 (B  (None, 25, 25, 32)           96        ['conv2d_430[0][0]']
#  atchNormalization)
#
#  batch_normalization_432 (B  (None, 25, 25, 32)           96        ['conv2d_432[0][0]']
#  atchNormalization)
#
#  batch_normalization_435 (B  (None, 25, 25, 64)           192       ['conv2d_435[0][0]']
#  atchNormalization)
#
#  activation_430 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_430[0][0
#  )                                                                  ]']
#
#  activation_432 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_432[0][0
#  )                                                                  ]']
#
#  activation_435 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_435[0][0
#  )                                                                  ]']
#
#  block35_3_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_430[0][0]',
#  te)                                                                 'activation_432[0][0]',
#                                                                      'activation_435[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_82 (Cus  (None, 25, 25, 320)          0         ['block35_2_ac[0][0]',
#  tomScaleLayer)                                                      'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_82[0][0]'
#                                                                     ]
#
#  conv2d_439 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_439 (B  (None, 25, 25, 32)           96        ['conv2d_439[0][0]']
#  atchNormalization)
#
#  activation_439 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_439[0][0
#  )                                                                  ]']
#
#  conv2d_437 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_440 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_439[0][0]']
#
#  batch_normalization_437 (B  (None, 25, 25, 32)           96        ['conv2d_437[0][0]']
#  atchNormalization)
#
#  batch_normalization_440 (B  (None, 25, 25, 48)           144       ['conv2d_440[0][0]']
#  atchNormalization)
#
#  activation_437 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_437[0][0
#  )                                                                  ]']
#
#  activation_440 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_440[0][0
#  )                                                                  ]']
#
#  conv2d_436 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_438 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_437[0][0]']
#
#  conv2d_441 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_440[0][0]']
#
#  batch_normalization_436 (B  (None, 25, 25, 32)           96        ['conv2d_436[0][0]']
#  atchNormalization)
#
#  batch_normalization_438 (B  (None, 25, 25, 32)           96        ['conv2d_438[0][0]']
#  atchNormalization)
#
#  batch_normalization_441 (B  (None, 25, 25, 64)           192       ['conv2d_441[0][0]']
#  atchNormalization)
#
#  activation_436 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_436[0][0
#  )                                                                  ]']
#
#  activation_438 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_438[0][0
#  )                                                                  ]']
#
#  activation_441 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_441[0][0
#  )                                                                  ]']
#
#  block35_4_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_436[0][0]',
#  te)                                                                 'activation_438[0][0]',
#                                                                      'activation_441[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_83 (Cus  (None, 25, 25, 320)          0         ['block35_3_ac[0][0]',
#  tomScaleLayer)                                                      'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_83[0][0]'
#                                                                     ]
#
#  conv2d_445 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_445 (B  (None, 25, 25, 32)           96        ['conv2d_445[0][0]']
#  atchNormalization)
#
#  activation_445 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_445[0][0
#  )                                                                  ]']
#
#  conv2d_443 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_446 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_445[0][0]']
#
#  batch_normalization_443 (B  (None, 25, 25, 32)           96        ['conv2d_443[0][0]']
#  atchNormalization)
#
#  batch_normalization_446 (B  (None, 25, 25, 48)           144       ['conv2d_446[0][0]']
#  atchNormalization)
#
#  activation_443 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_443[0][0
#  )                                                                  ]']
#
#  activation_446 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_446[0][0
#  )                                                                  ]']
#
#  conv2d_442 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_444 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_443[0][0]']
#
#  conv2d_447 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_446[0][0]']
#
#  batch_normalization_442 (B  (None, 25, 25, 32)           96        ['conv2d_442[0][0]']
#  atchNormalization)
#
#  batch_normalization_444 (B  (None, 25, 25, 32)           96        ['conv2d_444[0][0]']
#  atchNormalization)
#
#  batch_normalization_447 (B  (None, 25, 25, 64)           192       ['conv2d_447[0][0]']
#  atchNormalization)
#
#  activation_442 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_442[0][0
#  )                                                                  ]']
#
#  activation_444 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_444[0][0
#  )                                                                  ]']
#
#  activation_447 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_447[0][0
#  )                                                                  ]']
#
#  block35_5_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_442[0][0]',
#  te)                                                                 'activation_444[0][0]',
#                                                                      'activation_447[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_84 (Cus  (None, 25, 25, 320)          0         ['block35_4_ac[0][0]',
#  tomScaleLayer)                                                      'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_84[0][0]'
#                                                                     ]
#
#  conv2d_451 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_451 (B  (None, 25, 25, 32)           96        ['conv2d_451[0][0]']
#  atchNormalization)
#
#  activation_451 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_451[0][0
#  )                                                                  ]']
#
#  conv2d_449 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_452 (Conv2D)         (None, 25, 25, 48)           13824     ['activation_451[0][0]']
#
#  batch_normalization_449 (B  (None, 25, 25, 32)           96        ['conv2d_449[0][0]']
#  atchNormalization)
#
#  batch_normalization_452 (B  (None, 25, 25, 48)           144       ['conv2d_452[0][0]']
#  atchNormalization)
#
#  activation_449 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_449[0][0
#  )                                                                  ]']
#
#  activation_452 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_452[0][0
#  )                                                                  ]']
#
#  conv2d_448 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_450 (Conv2D)         (None, 25, 25, 32)           9216      ['activation_449[0][0]']
#
#  conv2d_453 (Conv2D)         (None, 25, 25, 64)           27648     ['activation_452[0][0]']
#
#  batch_normalization_448 (B  (None, 25, 25, 32)           96        ['conv2d_448[0][0]']
#  atchNormalization)
#
#  batch_normalization_450 (B  (None, 25, 25, 32)           96        ['conv2d_450[0][0]']
#  atchNormalization)
#
#  batch_normalization_453 (B  (None, 25, 25, 64)           192       ['conv2d_453[0][0]']
#  atchNormalization)
#
#  activation_448 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_448[0][0
#  )                                                                  ]']
#
#  activation_450 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_450[0][0
#  )                                                                  ]']
#
#  activation_453 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_453[0][0
#  )                                                                  ]']
#
#  block35_6_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_448[0][0]',
#  te)                                                                 'activation_450[0][0]',
#                                                                      'activation_453[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_85 (Cus  (None, 25, 25, 320)          0         ['block35_5_ac[0][0]',
#  tomScaleLayer)                                                      'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_85[0][0]'
#                                                                     ]
#
#  conv2d_457 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_457 (B  (None, 25, 25, 32)           96        ['conv2d_457[0][0]']
#  atchNormalization)
#
#  activation_457 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_457[0][0
#  )                                                                  ]']
#
#  conv2d_455 (Conv2D)         (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
# ...
#  activation_597 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_597[0][0
#  )                                                                  ]']
#
#  activation_600 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_600[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_597[0][0]',
#  e)                                                                  'activation_600[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_117 (Cu  (None, 5, 5, 2080)           0         ['block8_7_ac[0][0]',
#  stomScaleLayer)                                                     'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_117[0][0]
#                                                                     ']
#
#  conv2d_602 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_602 (B  (None, 5, 5, 192)            576       ['conv2d_602[0][0]']
#  atchNormalization)
#
#  activation_602 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_602[0][0
#  )                                                                  ]']
#
#  conv2d_603 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_602[0][0]']
#
#  batch_normalization_603 (B  (None, 5, 5, 224)            672       ['conv2d_603[0][0]']
#  atchNormalization)
#
#  activation_603 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_603[0][0
#  )                                                                  ]']
#
#  conv2d_601 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_604 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_603[0][0]']
#
#  batch_normalization_601 (B  (None, 5, 5, 192)            576       ['conv2d_601[0][0]']
#  atchNormalization)
#
#  batch_normalization_604 (B  (None, 5, 5, 256)            768       ['conv2d_604[0][0]']
#  atchNormalization)
#
#  activation_601 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_601[0][0
#  )                                                                  ]']
#
#  activation_604 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_604[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_601[0][0]',
#  e)                                                                  'activation_604[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_118 (Cu  (None, 5, 5, 2080)           0         ['block8_8_ac[0][0]',
#  stomScaleLayer)                                                     'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_118[0][0]
#                                                                     ']
#
#  conv2d_606 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_606 (B  (None, 5, 5, 192)            576       ['conv2d_606[0][0]']
#  atchNormalization)
#
#  activation_606 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_606[0][0
#  )                                                                  ]']
#
#  conv2d_607 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_606[0][0]']
#
#  batch_normalization_607 (B  (None, 5, 5, 224)            672       ['conv2d_607[0][0]']
#  atchNormalization)
#
#  activation_607 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_607[0][0
#  )                                                                  ]']
#
#  conv2d_605 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_608 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_607[0][0]']
#
#  batch_normalization_605 (B  (None, 5, 5, 192)            576       ['conv2d_605[0][0]']
#  atchNormalization)
#
#  batch_normalization_608 (B  (None, 5, 5, 256)            768       ['conv2d_608[0][0]']
#  atchNormalization)
#
#  activation_605 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_605[0][0
#  )                                                                  ]']
#
#  activation_608 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_608[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 5, 5, 448)            0         ['activation_605[0][0]',
#  te)                                                                 'activation_608[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 5, 5, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_119 (Cu  (None, 5, 5, 2080)           0         ['block8_9_ac[0][0]',
#  stomScaleLayer)                                                     'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 5, 5, 1536)           3194880   ['custom_scale_layer_119[0][0]
#                                                                     ']
#
#  conv_7b_bn (BatchNormaliza  (None, 5, 5, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 5, 5, 1536)           0         ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_4  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 1024)                 1573888   ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  dense_9 (Dense)             (None, 1)                    1025      ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 55911649 (213.29 MB)
# Trainable params: 55851105 (213.06 MB)
# Non-trainable params: 60544 (236.50 KB)
# __________________________________________________________________________________________________
# WARNING:tensorflow:EarlyStopping mode <built-in function min> is unknown, fallback to auto mode.
# Epoch 1/70
#
# Epoch 1: val_loss improved from inf to 21.81758, saving model to best_m.h5
# 11/11 - 108s - loss: 10.2557 - val_loss: 21.8176 - 108s/epoch - 10s/step
# Epoch 2/70
#
# Epoch 2: val_loss improved from 21.81758 to 11.90337, saving model to best_m.h5
# 11/11 - 22s - loss: 3.1673 - val_loss: 11.9034 - 22s/epoch - 2s/step
# Epoch 3/70
#
# Epoch 3: val_loss improved from 11.90337 to 6.18550, saving model to best_m.h5
# 11/11 - 27s - loss: 2.0727 - val_loss: 6.1855 - 27s/epoch - 2s/step
# Epoch 4/70
#
# Epoch 4: val_loss improved from 6.18550 to 4.90515, saving model to best_m.h5
# 11/11 - 25s - loss: 1.8399 - val_loss: 4.9052 - 25s/epoch - 2s/step
# Epoch 5/70
#
# Epoch 5: val_loss improved from 4.90515 to 2.65763, saving model to best_m.h5
# 11/11 - 19s - loss: 1.7152 - val_loss: 2.6576 - 19s/epoch - 2s/step
# Epoch 6/70
#
# Epoch 6: val_loss did not improve from 2.65763
# 11/11 - 14s - loss: 1.7121 - val_loss: 2.7147 - 14s/epoch - 1s/step
# Epoch 7/70
#
# Epoch 7: val_loss did not improve from 2.65763
# 11/11 - 14s - loss: 1.3734 - val_loss: 2.9038 - 14s/epoch - 1s/step
# Epoch 8/70
#
# Epoch 8: val_loss improved from 2.65763 to 2.38568, saving model to best_m.h5
# 11/11 - 23s - loss: 1.7305 - val_loss: 2.3857 - 23s/epoch - 2s/step
# Epoch 9/70
#
# Epoch 9: val_loss improved from 2.38568 to 2.23210, saving model to best_m.h5
# 11/11 - 23s - loss: 1.2235 - val_loss: 2.2321 - 23s/epoch - 2s/step
# Epoch 10/70
#
# Epoch 10: val_loss did not improve from 2.23210
# 11/11 - 14s - loss: 1.1604 - val_loss: 2.6855 - 14s/epoch - 1s/step
# Epoch 11/70
#
# Epoch 11: val_loss did not improve from 2.23210
# 11/11 - 14s - loss: 1.0815 - val_loss: 3.4371 - 14s/epoch - 1s/step
# Epoch 12/70
#
# Epoch 12: val_loss improved from 2.23210 to 2.16192, saving model to best_m.h5
# 11/11 - 20s - loss: 1.0520 - val_loss: 2.1619 - 20s/epoch - 2s/step
# Epoch 13/70
#
# Epoch 13: val_loss did not improve from 2.16192
# 11/11 - 14s - loss: 1.1315 - val_loss: 2.5678 - 14s/epoch - 1s/step
# Epoch 14/70
#
# Epoch 14: val_loss did not improve from 2.16192
# 11/11 - 14s - loss: 1.0126 - val_loss: 2.8676 - 14s/epoch - 1s/step
# Epoch 15/70
#
# Epoch 15: val_loss did not improve from 2.16192
# 11/11 - 14s - loss: 1.1036 - val_loss: 3.1364 - 14s/epoch - 1s/step
# Epoch 16/70
#
# Epoch 16: val_loss did not improve from 2.16192
# 11/11 - 14s - loss: 0.9927 - val_loss: 3.3298 - 14s/epoch - 1s/step
# Epoch 17/70
#
# Epoch 17: val_loss did not improve from 2.16192
# 11/11 - 14s - loss: 0.8793 - val_loss: 4.0799 - 14s/epoch - 1s/step
# Epoch 18/70
#
# Epoch 18: val_loss did not improve from 2.16192
# 11/11 - 14s - loss: 1.0003 - val_loss: 3.5670 - 14s/epoch - 1s/step
# Epoch 19/70
#
# Epoch 19: val_loss improved from 2.16192 to 2.01130, saving model to best_m.h5
# 11/11 - 27s - loss: 0.7264 - val_loss: 2.0113 - 27s/epoch - 2s/step
# Epoch 20/70
#
# Epoch 20: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.8294 - val_loss: 2.8767 - 14s/epoch - 1s/step
# Epoch 21/70
#
# Epoch 21: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.7331 - val_loss: 2.9391 - 14s/epoch - 1s/step
# Epoch 22/70
#
# Epoch 22: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.7503 - val_loss: 2.9703 - 14s/epoch - 1s/step
# Epoch 23/70
#
# Epoch 23: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.8027 - val_loss: 2.4787 - 14s/epoch - 1s/step
# Epoch 24/70
#
# Epoch 24: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.7099 - val_loss: 2.8590 - 14s/epoch - 1s/step
# Epoch 25/70
#
# Epoch 25: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.6820 - val_loss: 2.5825 - 14s/epoch - 1s/step
# Epoch 26/70
#
# Epoch 26: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.6740 - val_loss: 2.6987 - 14s/epoch - 1s/step
# Epoch 27/70
#
# Epoch 27: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.7306 - val_loss: 2.6964 - 14s/epoch - 1s/step
# Epoch 28/70
#
# Epoch 28: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.7029 - val_loss: 2.4260 - 14s/epoch - 1s/step
# Epoch 29/70
#
# Epoch 29: val_loss did not improve from 2.01130
# 11/11 - 14s - loss: 0.7860 - val_loss: 2.3528 - 14s/epoch - 1s/step
# Epoch 29: early stopping

# %% [markdown]
# # 5. Evaluacion del modelo con datos de testing

# %% [markdown]
# Evaluamos a continuacion el rendimiento de los 3 modelos con los datos de testing.

# %%
VGG16FineTuningModel.evaluate(test_generator, batch_size=128)
VGG16LastLayersModel.evaluate(test_generator, batch_size=128)
InceptionResNetV2FineTuningModel.evaluate(test_generator, batch_size=128)
# Out:
# 3/3 [==============================] - 8s 3s/step - loss: 1.2028
# 3/3 [==============================] - 1s 253ms/step - loss: 2.2769
# 3/3 [==============================] - 4s 2s/step - loss: 2.3650
# 2.3649988174438477

# %% [markdown]
# Para verlo de una manera mas intuitiva, imprimimos los resultados reales junto con sus valores predichos por los distintos modelos implementados.

# %%
predictionsVGG16_FineTuningModel = VGG16FineTuningModel.predict(test_generator, verbose=1)
predictionsVGG16_LastLayersModel= VGG16LastLayersModel.predict(test_generator, verbose=1)
predictionsInceptionResNetV2_FineTuningModel = InceptionResNetV2FineTuningModel.predict(test_generator, verbose=1)

for i in range(0, len(test_data)):
  print("\n Ejemplo", i)
  print("\t Imagen: ", test_data.iloc[i, 0])
  print("\t Porcentaje predicho por VGG16 con Fine Tuning: ", predictionsVGG16_FineTuningModel[i])
  print("\t Porcentaje predicho por VGG16 con ultimas capas entrenadas: ", predictionsVGG16_LastLayersModel[i])
  print("\t Porcentaje predicho por InceptionResNetV2 con Fine Tuning: ", predictionsInceptionResNetV2_FineTuningModel[i])
  print("\t Porcentaje real: ", test_data.iloc[i, 1])
# Out:
# 3/3 [==============================] - 1s 351ms/step
# 3/3 [==============================] - 1s 334ms/step
# 3/3 [==============================] - 4s 364ms/step
#
#  Ejemplo 0
# 	 Imagen:  20151211_122813.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.70737]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.828028]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [16.5607]
# 	 Porcentaje real:  18.09882067
#
#  Ejemplo 1
# 	 Imagen:  20151211_124745.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [23.852016]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [24.527464]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [18.494036]
# 	 Porcentaje real:  24.47016822
#
#  Ejemplo 2
# 	 Imagen:  20151204_130806.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.851699]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [13.761499]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.920139]
# 	 Porcentaje real:  14.56150679
#
#  Ejemplo 3
# 	 Imagen:  20151211_130428.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.647326]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.184277]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.070595]
# 	 Porcentaje real:  10.44463818
#
#  Ejemplo 4
# 	 Imagen:  20151221_131723.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.096395]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.563952]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.318427]
# 	 Porcentaje real:  15.12974777
#
#  Ejemplo 5
# 	 Imagen:  20151130_115848.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.604529]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.613366]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.058457]
# 	 Porcentaje real:  11.706823
#
#  Ejemplo 6
# 	 Imagen:  20151130_121249.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.743256]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.706975]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.567317]
# 	 Porcentaje real:  17.50360939
#
#  Ejemplo 7
# 	 Imagen:  20151221_125807.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.915817]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.864977]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.41819]
# 	 Porcentaje real:  16.44100476
#
#  Ejemplo 8
# 	 Imagen:  20151221_120547.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [6.835643]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [6.922198]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [5.679286]
# 	 Porcentaje real:  6.188337518
#
#  Ejemplo 9
# 	 Imagen:  20151221_134140.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.475888]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.710726]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.534076]
# 	 Porcentaje real:  14.67752287
#
#  Ejemplo 10
# 	 Imagen:  20151127_134327.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [10.996269]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.188235]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.191792]
# 	 Porcentaje real:  9.971975923
#
#  Ejemplo 11
# 	 Imagen:  20151130_121353.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.0211396]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [6.70652]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [4.779688]
# 	 Porcentaje real:  6.51750028
#
#  Ejemplo 12
# 	 Imagen:  20151130_122155.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.120724]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.854124]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.582064]
# 	 Porcentaje real:  16.3189939
#
#  Ejemplo 13
# 	 Imagen:  20151203_125258.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [24.154823]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [29.575869]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [22.448845]
# 	 Porcentaje real:  25.02150115
#
#  Ejemplo 14
# 	 Imagen:  20151203_121413.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.120192]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.290123]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.1580715]
# 	 Porcentaje real:  12.45443209
#
#  Ejemplo 15
# 	 Imagen:  20151127_120002.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.145374]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [20.8161]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.436403]
# 	 Porcentaje real:  16.29262433
#
#  Ejemplo 16
# 	 Imagen:  20151130_121642.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.052643]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [18.37317]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [16.250027]
# 	 Porcentaje real:  18.63972841
#
#  Ejemplo 17
# 	 Imagen:  20151221_125345.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.442301]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.390508]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.29669]
# 	 Porcentaje real:  8.510486251
#
#  Ejemplo 18
# 	 Imagen:  20151204_134303.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [8.603254]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.476155]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [7.5144076]
# 	 Porcentaje real:  7.98833882
#
#  Ejemplo 19
# 	 Imagen:  20151221_125957.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.844295]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [7.861329]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [6.0492806]
# 	 Porcentaje real:  7.168679614
#
#  Ejemplo 20
# 	 Imagen:  20151221_123544.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.3267565]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.728654]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.749929]
# 	 Porcentaje real:  14.67205372
#
#  Ejemplo 21
# 	 Imagen:  20151204_123118.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.298685]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.746901]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.191269]
# 	 Porcentaje real:  18.07571757
#
#  Ejemplo 22
# 	 Imagen:  20151211_121401.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [22.990936]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [24.788843]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [18.861046]
# 	 Porcentaje real:  19.46354267
#
#  Ejemplo 23
# 	 Imagen:  20151204_123621.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.95824]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.455679]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.297856]
# 	 Porcentaje real:  16.10236798
#
#  Ejemplo 24
# 	 Imagen:  20151127_133941.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [21.444992]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [21.970789]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [18.812706]
# 	 Porcentaje real:  20.24072522
#
#  Ejemplo 25
# 	 Imagen:  20151130_120108.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.876646]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.732779]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.414488]
# 	 Porcentaje real:  18.2402927
#
#  Ejemplo 26
# 	 Imagen:  20151203_125246.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [24.884575]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [24.88582]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [19.936104]
# 	 Porcentaje real:  24.36536578
#
#  Ejemplo 27
# 	 Imagen:  20151130_121302.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.712214]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [19.83624]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.901115]
# 	 Porcentaje real:  18.32254271
#
#  Ejemplo 28
# 	 Imagen:  20151211_132746.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.462395]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.53963]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.001883]
# 	 Porcentaje real:  18.17570165
#
#  Ejemplo 29
# 	 Imagen:  20151221_122607.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [8.634029]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.253833]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [6.206378]
# 	 Porcentaje real:  7.27925157
#
#  Ejemplo 30
# 	 Imagen:  20151204_120630.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.883374]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.610942]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.8137455]
# 	 Porcentaje real:  13.16065335
#
#  Ejemplo 31
# 	 Imagen:  20151221_134800.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.488379]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.782296]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.751057]
# 	 Porcentaje real:  17.14410974
#
#  Ejemplo 32
# 	 Imagen:  20151130_113525.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.776202]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.176446]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.036512]
# 	 Porcentaje real:  15.52112369
#
#  Ejemplo 33
# 	 Imagen:  20151211_134033.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.283984]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.421624]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.439217]
# 	 Porcentaje real:  13.73944466
#
#  Ejemplo 34
# 	 Imagen:  20151211_132926.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.25739]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.893585]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.45916]
# 	 Porcentaje real:  15.93020863
#
#  Ejemplo 35
# 	 Imagen:  20151127_123447.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.856926]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.340578]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.154797]
# 	 Porcentaje real:  15.31659999
#
#  Ejemplo 36
# 	 Imagen:  20151127_121906.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [10.604222]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.667244]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [8.905621]
# 	 Porcentaje real:  10.41854395
#
#  Ejemplo 37
# 	 Imagen:  20151211_113730.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.390742]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [13.335117]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.300102]
# 	 Porcentaje real:  13.78777844
#
#  Ejemplo 38
# 	 Imagen:  20151211_122524.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.83282]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [20.694777]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [16.194414]
# 	 Porcentaje real:  18.64468444
#
#  Ejemplo 39
# 	 Imagen:  20151127_134203.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.451136]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.518298]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.257411]
# 	 Porcentaje real:  17.02390106
#
#  Ejemplo 40
# 	 Imagen:  20151203_122955.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.597097]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [18.792212]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [17.61248]
# 	 Porcentaje real:  19.16533004
#
#  Ejemplo 41
# 	 Imagen:  20151204_123744.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.708407]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.864448]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.776102]
# 	 Porcentaje real:  12.23909524
#
#  Ejemplo 42
# 	 Imagen:  20151127_115424.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.019061]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [13.036262]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.333309]
# 	 Porcentaje real:  15.65454843
#
#  Ejemplo 43
# 	 Imagen:  20151127_121649.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.714166]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.476229]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.000849]
# 	 Porcentaje real:  15.086345
#
#  Ejemplo 44
# 	 Imagen:  20151211_132631.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [6.7811465]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [7.3066626]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [4.9019547]
# 	 Porcentaje real:  6.326893502
#
#  Ejemplo 45
# 	 Imagen:  20151127_130638.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.117853]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.106362]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.492479]
# 	 Porcentaje real:  16.57101285
#
#  Ejemplo 46
# 	 Imagen:  20151221_120054.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [11.303201]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.168113]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.497898]
# 	 Porcentaje real:  10.44853041
#
#  Ejemplo 47
# 	 Imagen:  20151221_113350.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.872576]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [18.209375]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.407942]
# 	 Porcentaje real:  17.15770126
#
#  Ejemplo 48
# 	 Imagen:  20151221_124149.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.4331493]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [8.40385]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [5.2849174]
# 	 Porcentaje real:  6.884083546
#
#  Ejemplo 49
# 	 Imagen:  20151211_133922.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.115798]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [10.724542]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.024159]
# 	 Porcentaje real:  13.47277039
#
#  Ejemplo 50
# 	 Imagen:  20151221_134106.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [9.882194]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [10.443004]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [7.3176727]
# 	 Porcentaje real:  9.177059304
#
#  Ejemplo 51
# 	 Imagen:  20151211_140855.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.120259]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.6727]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.500209]
# 	 Porcentaje real:  11.95504984
#
#  Ejemplo 52
# 	 Imagen:  20151221_134206.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [11.020625]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [11.478396]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.195776]
# 	 Porcentaje real:  9.942727857
#
#  Ejemplo 53
# 	 Imagen:  20151127_131852.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [9.123132]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.986669]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [7.8242626]
# 	 Porcentaje real:  9.011207628
#
#  Ejemplo 54
# 	 Imagen:  20151127_123652.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [28.930649]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [28.447342]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [25.370975]
# 	 Porcentaje real:  26.92063549
#
#  Ejemplo 55
# 	 Imagen:  20151204_131917.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [10.125514]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [11.895701]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [8.184075]
# 	 Porcentaje real:  11.59560025
#
#  Ejemplo 56
# 	 Imagen:  20151127_141102.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.459057]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.291157]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.603411]
# 	 Porcentaje real:  17.43630254
#
#  Ejemplo 57
# 	 Imagen:  20151204_113948.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [8.910348]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.037018]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [7.26345]
# 	 Porcentaje real:  6.375202246
#
#  Ejemplo 58
# 	 Imagen:  20151130_120318.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.247651]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.176013]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.988142]
# 	 Porcentaje real:  14.386106
#
#  Ejemplo 59
# 	 Imagen:  20151127_125347.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.810402]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.578752]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.998585]
# 	 Porcentaje real:  12.58920848
#
#  Ejemplo 60
# 	 Imagen:  20151127_135544.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.303171]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.700702]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.188454]
# 	 Porcentaje real:  18.43153775
#
#  Ejemplo 61
# 	 Imagen:  20151221_131909.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [9.224822]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [8.862409]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [7.109947]
# 	 Porcentaje real:  9.146484625
#
#  Ejemplo 62
# 	 Imagen:  20151211_142609.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.124895]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.902365]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [17.042713]
# 	 Porcentaje real:  19.75758773
#
#  Ejemplo 63
# 	 Imagen:  20151127_142534.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.459759]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [18.245604]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.492591]
# 	 Porcentaje real:  18.0461316
#
#  Ejemplo 64
# 	 Imagen:  20151204_123807.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [11.691748]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.182579]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.846217]
# 	 Porcentaje real:  11.03894836
#
#  Ejemplo 65
# 	 Imagen:  20151203_123344.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [9.203769]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.15465]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [6.20677]
# 	 Porcentaje real:  7.830859826
#
#  Ejemplo 66
# 	 Imagen:  20151204_121303.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [10.646941]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [10.036556]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [8.369997]
# 	 Porcentaje real:  9.963891092
#
#  Ejemplo 67
# 	 Imagen:  20151211_130817.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [20.419838]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [18.126179]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [17.58091]
# 	 Porcentaje real:  20.00075842
#
#  Ejemplo 68
# 	 Imagen:  20151203_131227.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.430504]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [19.522696]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.445999]
# 	 Porcentaje real:  16.89493174
#
#  Ejemplo 69
# 	 Imagen:  20151203_132207.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.698079]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [13.138701]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.208751]
# 	 Porcentaje real:  12.1429283
#
#  Ejemplo 70
# 	 Imagen:  20151221_135010.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.640034]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.543653]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.098043]
# 	 Porcentaje real:  17.60839931
#
#  Ejemplo 71
# 	 Imagen:  20151211_123531.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [9.00154]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [10.753659]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [7.3300133]
# 	 Porcentaje real:  8.050927428
#
#  Ejemplo 72
# 	 Imagen:  20151127_133130.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.305555]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.7452545]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.457148]
# 	 Porcentaje real:  17.40163539
#
#  Ejemplo 73
# 	 Imagen:  20151211_121925.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [6.624636]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [8.744224]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [5.136962]
# 	 Porcentaje real:  6.634454997
#
#  Ejemplo 74
# 	 Imagen:  20151204_131306.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.0951]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.854558]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [5.163701]
# 	 Porcentaje real:  6.748080666
#
#  Ejemplo 75
# 	 Imagen:  20151130_115115.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.27147]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.572916]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [16.047497]
# 	 Porcentaje real:  17.98919987
#
#  Ejemplo 76
# 	 Imagen:  20151204_122112.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.051923]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.426723]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.581939]
# 	 Porcentaje real:  11.54058335
#
#  Ejemplo 77
# 	 Imagen:  20151221_130104.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [6.0744896]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [6.5412755]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [3.8248513]
# 	 Porcentaje real:  6.105812168
#
#  Ejemplo 78
# 	 Imagen:  20151204_123954.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.659467]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.567146]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.523214]
# 	 Porcentaje real:  13.17842496
#
#  Ejemplo 79
# 	 Imagen:  20151204_124035.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.27891]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.121146]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.201138]
# 	 Porcentaje real:  13.35039658
#
#  Ejemplo 80
# 	 Imagen:  20151127_130819.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.035372]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.25812]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [18.17332]
# 	 Porcentaje real:  18.31634768
#
#  Ejemplo 81
# 	 Imagen:  20151211_135719.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.1215124]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [6.483876]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [4.900385]
# 	 Porcentaje real:  6.459379606
#
#  Ejemplo 82
# 	 Imagen:  20151130_121212.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [11.017442]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [13.484147]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [7.6435275]
# 	 Porcentaje real:  9.03135713
#
#  Ejemplo 83
# 	 Imagen:  20151221_113328.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.4161005]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [7.3877025]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [5.392231]
# 	 Porcentaje real:  6.35854449
#
#  Ejemplo 84
# 	 Imagen:  20151204_122613.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.865429]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.11762]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.841524]
# 	 Porcentaje real:  19.11113915
#
#  Ejemplo 85
# 	 Imagen:  20151221_134925.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.415226]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.5853]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.800946]
# 	 Porcentaje real:  14.65579645
#
#  Ejemplo 86
# 	 Imagen:  20151221_115117.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.924955]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [20.637941]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.300346]
# 	 Porcentaje real:  16.25919618
#
#  Ejemplo 87
# 	 Imagen:  20151221_122545.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [8.513135]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.86375]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [6.1424513]
# 	 Porcentaje real:  7.35429282
#
#  Ejemplo 88
# 	 Imagen:  20151221_130150.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.329023]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [10.879512]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [6.414686]
# 	 Porcentaje real:  6.505348003
#
#  Ejemplo 89
# 	 Imagen:  20151204_124232.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [25.609207]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [29.55852]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [19.96474]
# 	 Porcentaje real:  25.53427468
#
#  Ejemplo 90
# 	 Imagen:  20151130_114818.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.43198]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [19.223951]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.272879]
# 	 Porcentaje real:  18.62642473
#
#  Ejemplo 91
# 	 Imagen:  20151211_134625.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.071048]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.894115]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.690796]
# 	 Porcentaje real:  11.94323547
#
#  Ejemplo 92
# 	 Imagen:  20151221_135140.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.711754]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.255248]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.290635]
# 	 Porcentaje real:  15.75798671
#
#  Ejemplo 93
# 	 Imagen:  20151221_135021.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.874337]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.149331]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.506294]
# 	 Porcentaje real:  12.89405417
#
#  Ejemplo 94
# 	 Imagen:  20151204_123129.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.250462]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.375212]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.708082]
# 	 Porcentaje real:  17.25399336
#
#  Ejemplo 95
# 	 Imagen:  20151130_120259.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.281404]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.581581]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.207084]
# 	 Porcentaje real:  17.49590001
#
#  Ejemplo 96
# 	 Imagen:  20151130_121105.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.584751]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.686367]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.505074]
# 	 Porcentaje real:  17.02094747
#
#  Ejemplo 97
# 	 Imagen:  20151127_122446.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.642225]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [20.26167]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [17.250027]
# 	 Porcentaje real:  17.02850666
#
#  Ejemplo 98
# 	 Imagen:  20151221_120520.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.444313]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.968336]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.874506]
# 	 Porcentaje real:  13.04124565
#
#  Ejemplo 99
# 	 Imagen:  20151211_132209.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.74282]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.488622]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.837328]
# 	 Porcentaje real:  14.91327204
#
#  Ejemplo 100
# 	 Imagen:  20151211_121043.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [22.713568]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [20.651009]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [19.492592]
# 	 Porcentaje real:  21.88771546
#
#  Ejemplo 101
# 	 Imagen:  20151211_141852.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.839443]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.867563]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.207602]
# 	 Porcentaje real:  16.04974149
#
#  Ejemplo 102
# 	 Imagen:  20151204_133704.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [5.7976575]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [6.8356]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [3.7915971]
# 	 Porcentaje real:  5.585116502
#
#  Ejemplo 103
# 	 Imagen:  20151204_134947.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [5.617785]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [4.5271244]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [3.8404448]
# 	 Porcentaje real:  4.967653166
#
#  Ejemplo 104
# 	 Imagen:  20151221_131046.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.285537]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.163471]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.353861]
# 	 Porcentaje real:  12.74563619
#
#  Ejemplo 105
# 	 Imagen:  20151211_125829.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [20.021965]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.43161]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [16.672827]
# 	 Porcentaje real:  19.18208792
#
#  Ejemplo 106
# 	 Imagen:  20151204_114821.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.879073]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.941255]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.649588]
# 	 Porcentaje real:  12.09306767
#
#  Ejemplo 107
# 	 Imagen:  20151211_140619.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [5.8286433]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [7.32221]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [4.667552]
# 	 Porcentaje real:  5.303123598
#
#  Ejemplo 108
# 	 Imagen:  20151204_133527.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.962186]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.5798025]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.087514]
# 	 Porcentaje real:  12.99493935
#
#  Ejemplo 109
# 	 Imagen:  20151127_121953.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.420864]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.423672]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.958803]
# 	 Porcentaje real:  19.11859822
#
#  Ejemplo 110
# 	 Imagen:  20151211_132821.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.212611]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.403223]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.367912]
# 	 Porcentaje real:  14.33062604
#
#  Ejemplo 111
# 	 Imagen:  20151211_130450.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.089007]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [13.82486]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.262931]
# 	 Porcentaje real:  14.80596656
#
#  Ejemplo 112
# 	 Imagen:  20151221_123510.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.099968]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.488459]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.339769]
# 	 Porcentaje real:  17.5453977
#
#  Ejemplo 113
# 	 Imagen:  20151221_125231.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.776928]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.96234]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [16.122385]
# 	 Porcentaje real:  14.44094769
#
#  Ejemplo 114
# 	 Imagen:  20151211_135141.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [6.6825337]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [7.057106]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [4.9083314]
# 	 Porcentaje real:  6.122732743
#
#  Ejemplo 115
# 	 Imagen:  20151127_134959.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [9.107308]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.164251]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [5.4139085]
# 	 Porcentaje real:  8.55739329
#
#  Ejemplo 116
# 	 Imagen:  20151203_122815.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.007589]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.970503]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.080208]
# 	 Porcentaje real:  11.97696399
#
#  Ejemplo 117
# 	 Imagen:  20151204_120318.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [5.292974]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [4.0735874]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [3.7307594]
# 	 Porcentaje real:  5.069677228
#
#  Ejemplo 118
# 	 Imagen:  20151221_114603.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [21.556377]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [24.771502]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [19.975166]
# 	 Porcentaje real:  20.43340953
#
#  Ejemplo 119
# 	 Imagen:  20151127_125520.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.69515]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.278032]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.628299]
# 	 Porcentaje real:  14.75659402
#
#  Ejemplo 120
# 	 Imagen:  20151211_121727.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.767648]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.475245]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.818018]
# 	 Porcentaje real:  12.65347412
#
#  Ejemplo 121
# 	 Imagen:  20151204_131904.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.27889]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [8.395873]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [6.5420012]
# 	 Porcentaje real:  6.121368584
#
#  Ejemplo 122
# 	 Imagen:  20151204_120924.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [6.680039]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [7.2359953]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [4.2926135]
# 	 Porcentaje real:  6.424036629
#
#  Ejemplo 123
# 	 Imagen:  20151204_120442.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [20.054424]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [22.12801]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [17.719816]
# 	 Porcentaje real:  20.8708915
#
#  Ejemplo 124
# 	 Imagen:  20151203_124558.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.009605]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [22.723833]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [18.246044]
# 	 Porcentaje real:  19.14703279
#
#  Ejemplo 125
# 	 Imagen:  20151204_124139.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.02515]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.553396]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.830114]
# 	 Porcentaje real:  15.44936142
#
#  Ejemplo 126
# 	 Imagen:  20151211_133341.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.83919]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.704327]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.029339]
# 	 Porcentaje real:  16.58810864
#
#  Ejemplo 127
# 	 Imagen:  20151211_115609.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.133826]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.352686]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.6647835]
# 	 Porcentaje real:  12.32200856
#
#  Ejemplo 128
# 	 Imagen:  20151221_122024.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.349716]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [11.711175]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.647783]
# 	 Porcentaje real:  13.79895453
#
#  Ejemplo 129
# 	 Imagen:  20151130_114034.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.407745]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [20.333605]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.966162]
# 	 Porcentaje real:  17.09984341
#
#  Ejemplo 130
# 	 Imagen:  20151204_130950.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [12.819012]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [14.266234]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [11.674817]
# 	 Porcentaje real:  12.30448726
#
#  Ejemplo 131
# 	 Imagen:  20151211_131312.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [23.798094]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [23.476831]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [19.202961]
# 	 Porcentaje real:  22.75786106
#
#  Ejemplo 132
# 	 Imagen:  20151204_113400.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [4.5288033]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [4.7186594]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [3.7670662]
# 	 Porcentaje real:  4.234436575
#
#  Ejemplo 133
# 	 Imagen:  20151204_131702.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.302242]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.813604]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.506252]
# 	 Porcentaje real:  15.44740905
#
#  Ejemplo 134
# 	 Imagen:  20151127_121213.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.362564]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.648401]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.835421]
# 	 Porcentaje real:  18.83884554
#
#  Ejemplo 135
# 	 Imagen:  20151204_115241.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.895872]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [21.970839]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [16.314114]
# 	 Porcentaje real:  16.23432844
#
#  Ejemplo 136
# 	 Imagen:  20151130_120353.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.172441]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.246073]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.177078]
# 	 Porcentaje real:  18.44840826
#
#  Ejemplo 137
# 	 Imagen:  20151211_123004.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [7.596658]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [9.564919]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [6.659979]
# 	 Porcentaje real:  7.300952959
#
#  Ejemplo 138
# 	 Imagen:  20151203_130726.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [16.369015]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [17.964333]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.200548]
# 	 Porcentaje real:  15.04394344
#
#  Ejemplo 139
# 	 Imagen:  20151211_131025.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [8.528165]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [7.561602]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [7.678274]
# 	 Porcentaje real:  8.006410796
#
#  Ejemplo 140
# 	 Imagen:  20151211_120752.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [9.017287]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [10.699164]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [6.4218345]
# 	 Porcentaje real:  8.070426138
#
#  Ejemplo 141
# 	 Imagen:  20151204_123518.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.025305]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.728127]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.694067]
# 	 Porcentaje real:  17.6948169
#
#  Ejemplo 142
# 	 Imagen:  20151221_114930.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.784943]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.634893]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.384226]
# 	 Porcentaje real:  17.45054486
#
#  Ejemplo 143
# 	 Imagen:  20151203_123019.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.058243]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [19.571075]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [14.811999]
# 	 Porcentaje real:  16.68833051
#
#  Ejemplo 144
# 	 Imagen:  20151204_121926.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.949592]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [18.120117]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.901148]
# 	 Porcentaje real:  15.70672438
#
#  Ejemplo 145
# 	 Imagen:  20151127_134537.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [22.931524]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [19.233633]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [19.766144]
# 	 Porcentaje real:  23.37736438
#
#  Ejemplo 146
# 	 Imagen:  20151211_140606.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [11.288214]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [11.190053]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.238504]
# 	 Porcentaje real:  10.91358342
#
#  Ejemplo 147
# 	 Imagen:  20151204_132129.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [15.284089]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [16.753214]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [12.772189]
# 	 Porcentaje real:  13.68084841
#
#  Ejemplo 148
# 	 Imagen:  20151127_122428.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [13.409848]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.616876]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [9.959634]
# 	 Porcentaje real:  10.77729269
#
#  Ejemplo 149
# 	 Imagen:  20151203_124353.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [22.583662]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [19.399319]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [20.31999]
# 	 Porcentaje real:  21.50038196
#
#  Ejemplo 150
# 	 Imagen:  20151211_125736.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.7355]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [20.29212]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [16.24112]
# 	 Porcentaje real:  19.01163064
#
#  Ejemplo 151
# 	 Imagen:  20151211_121353.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [17.187498]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [13.034047]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [13.974583]
# 	 Porcentaje real:  17.1791148
#
#  Ejemplo 152
# 	 Imagen:  20151221_115237.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [14.003654]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [12.027126]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [10.974828]
# 	 Porcentaje real:  13.49434663
#
#  Ejemplo 153
# 	 Imagen:  20151211_134530.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [19.302608]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [15.064459]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.300915]
# 	 Porcentaje real:  18.23832781
#
#  Ejemplo 154
# 	 Imagen:  20151211_115842.jpg
# 	 Porcentaje predicho por VGG16 con Fine Tuning:  [18.137539]
# 	 Porcentaje predicho por VGG16 con ultimas capas entrenadas:  [18.466484]
# 	 Porcentaje predicho por InceptionResNetV2 con Fine Tuning:  [15.470925]
# 	 Porcentaje real:  17.0592065
